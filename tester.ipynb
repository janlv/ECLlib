# %%
from pathlib import Path
from ECLlib import ECL_input

root = Path.home() / 'github' / 'ECLlib' / 'tests' / 'EKOFISK_HAUKAAS_2014' / 'EKOFISK_HAUKAAS_2014'

ecl = ECL_input(root)
ecl.wells_by_type()
ecl.wellpos_by_name
# Out:
# {'A-2': ((24, 41, 2), (24, 41, 3), (24, 41, 6), (24, 41, 8), (24, 41, 9)),
#  'A-21-AT2': ((35, 26, 2),
#   (35, 26, 4),
#   (35, 24, 9),
#   (36, 23, 9),
#   (36, 22, 9),
#   (36, 21, 9),
#   (37, 21, 9),
#   (37, 20, 9),
#   (37, 19, 9),
#   (38, 19, 9),
#   (38, 17, 9),
#   (39, 16, 9),
#   (39, 15, 9)),
#  'A-2-AT2': ((24, 39, 2),
#   (24, 38, 4),
#   (24, 38, 8),
#   (24, 37, 9),
#   (24, 36, 9),
#   (25, 35, 9),
#   (25, 34, 9),
#   (25, 32, 9),
#   (25, 31, 9),
#   (25, 30, 9),
#   (26, 29, 9),
#   (26, 28, 8),
#   (26, 27, 8),
#   (26, 26, 8),
#   (26, 25, 6),
#   (27, 24, 6),
#   (27, 23, 6),
#   (27, 21, 4),
#   (27, 20, 4),
#   (27, 19, 3),
#   (27, 18, 2),
#   (24, 38, 4),
#   (24, 38, 8),
#   (25, 35, 9),
#   (25, 34, 9),
#   (26, 27, 8),
#   (27, 23, 6)),
#  'A-5': ((15, 32, 1),
#   (15, 32, 2),
#   (15, 32, 3),
#   (15, 31, 3),
#   (15, 31, 4),
#   (15, 31, 5),
#   (15, 31, 6),
#   (15, 31, 7),
#   (15, 31, 8),
#   (15, 31, 9)),
#  'A-7-T2': ((22, 56, 2),
# ...

# %%
import numpy as np
from ECLlib import UNSMRY_file

root = "/home/AD.NORCERESEARCH.NO/javi/ekofisk/input/Line_Model_From_IXF/Line_Model_From_IXF"
#root = "/home/AD.NORCERESEARCH.NO/javi/ekofisk/input/Slice_Model_From_IXF/Slice_Model_From_IXF"
#root = "/home/AD.NORCERESEARCH.NO/javi/ekofisk/input/Model_From_IXF/Model_From_IXF"

unsmry = UNSMRY_file(root)
#it = unsmry.num_indexed_vectors(keys="CWVFR", only_new=True)
#for day, vals in it:
#    print(day, vals)
#next((key, unsmry.spec.data.measures[i]) for i, key in enumerate(unsmry.spec.data.keys) if key.startswith("CWVFR"))
#unsmry.spec.data.nums
#keys =  ("CW", "VF", "FR")
#unsmry.spec.meta(*keys)
vec = unsmry.num_indexed_vectors(keys='CWVFR', only_new=True)
list(vec)
#unsmry.spec.meta(*keys)
#[key for key in unsmry.spec.list_keys() if key.startswith(keys)]
#[m for m in unsmry.spec._vector_meta if m.key.startswith(("CW", "VF", "FR"))]

#day, vals = next(it)   # vals: tuple of NumIndexedValue(key, well, num, ijk, value)
#day, vals
#welldata = unsmry.iter_welldata(keys='CWVFR')
#next(welldata)
# Out:
# [(0.0,
#   (KeyIndexedValues(key='CWVFR', groups=(NameIndexedValues(name='INJECTOR', pos=(array([0]), array([0]), array([0])), values=array([0.], dtype='>f4')), NameIndexedValues(name='PRODUCER', pos=(array([24]), array([0]), array([0])), values=array([0.], dtype='>f4')))),)),
#  (0.125,
#   (KeyIndexedValues(key='CWVFR', groups=(NameIndexedValues(name='INJECTOR', pos=(array([0]), array([0]), array([0])), values=array([-582.93695], dtype='>f4')), NameIndexedValues(name='PRODUCER', pos=(array([24]), array([0]), array([0])), values=array([0.], dtype='>f4')))),)),
#  (0.19665324687957764,
#   (KeyIndexedValues(key='CWVFR', groups=(NameIndexedValues(name='INJECTOR', pos=(array([0]), array([0]), array([0])), values=array([-475.87497], dtype='>f4')), NameIndexedValues(name='PRODUCER', pos=(array([24]), array([0]), array([0])), values=array([0.], dtype='>f4')))),)),
#  (0.25293785333633423,
# ...
